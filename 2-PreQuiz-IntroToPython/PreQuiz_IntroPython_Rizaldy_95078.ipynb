# %%
import numpy
import pandas as pd
import os
import sys

# %%
os.getcwd()
# Out:
# 'D:\\OneDrive - PT Telekomunikasi Selular\\Work - Telkomsel\\Telkomsel Next-Gen Associate\\HCM Development\\Data Science Academy\\Exercise\\Pre-Quiz - Intro to Python'

# %%
imdb = pd.read_csv("IMDB-database-update.csv", encoding='latin1')

# %%
imdb.describe()
# Out:
#           movie_ID     duration        color   title_year    budget_USD  \
# count  3781.000000  3781.000000  3781.000000  3781.000000  3.781000e+03
# mean   1891.000000   109.950278     0.967204  2003.081989  4.572770e+07
# std    1091.625012    22.299267     0.178125     9.837954  2.252895e+08
# min       1.000000    37.000000     0.000000  1927.000000  2.180000e+02
# 25%     946.000000    95.000000     1.000000  1999.000000  1.000000e+07
# 50%    1891.000000   106.000000     1.000000  2005.000000  2.500000e+07
# 75%    2836.000000   120.000000     1.000000  2010.000000  5.000000e+07
# max    3781.000000   325.000000     1.000000  2016.000000  1.221550e+10
#
#           gross_USD       net_USD   profitable  director_facebook?  \
# count  3.781000e+03  3.781000e+03  3781.000000         3781.000000
# mean   5.182002e+07  6.092318e+06     0.531870            0.828352
# std    7.003776e+07  2.291199e+08     0.499049            0.377124
# ...

# %%
imdb = imdb.drop_duplicates()

# %%
imdb.count()
# Out:
# movie_ID                     3781
# movie_title                  3781
# duration                     3781
# color                        3781
# title_year                   3781
# country                      3781
# language                     3781
# content_rating               3781
# budget_USD                   3781
# gross_USD                    3781
# net_USD                      3781
# profitable                   3781
# director_name                3781
# director_top20?              3781
# director_facebook?           3781
# director_facebook_likes      3781
# actor_1_name                 3781
# actor_top20?                 3781
# actor_1_facebook?            3781
# actor_1_facebook_likes       3781
# actor_2_name                 3781
# actor_top20?.1               3781
# actor_2_facebook?            3781
# actor_2_facebook_likes       3781
# actor_3_name                 3781
# actor_top20?.2               3781
# actor_3_facebook?            3781
# ...

# %%
imdb[(imdb['title_year'] == 2015)].sort_values(['net_USD'])
# Out:
#       movie_ID                               movie_title  duration  color  \
# 1597      1598                         Jupiter Ascending       127      1
# 3533      3534                                       Pan       111      1
# 3401      3402                                       Pan       111      1
# 3393      3394                                       Pan       111      1
# 2572      2573                              Tomorrowland       130      1
# 1695      1696                         The Little Prince       108      1
# 1644      1645                               Point Break       114      1
# 2082      2083                               Point Break       114      1
# 148        149                   In the Heart of the Sea       122      1
# 2576      2577                        Terminator Genisys       126      1
# 3147      3148                              Dragon Blade       103      1
# 3117      3118                            Fantastic Four       100      1
# ...

# %%
imdb[(imdb['title_year'] == 2016)].sort_values(['gross_USD'])
# Out:
#       movie_ID                         movie_title  duration  color  \
# 1366      1367                    The Masked Saint       105      1
# 2999      3000                      The Neon Demon       118      1
# 765        766                      Jane Got a Gun        98      1
# 3048      3049                           Compadres       101      1
# 914        915                    Midnight Special       112      1
# 939        940                   The Young Messiah       111      1
# 3674      3675                   The Perfect Match        96      1
# 687        688     Pride and Prejudice and Zombies       108      1
# 3529      3530               Fifty Shades of Black        92      1
# 3263      3264                            Triple 9       115      1
# 2764      2765                            Criminal       113      1
# 1850      1851                     The Infiltrator       127      1
# 3241      3242                     Eddie the Eagle       106      1
# ...

# %%
imdb.groupby('language').nunique()
# Out:
#             movie_ID  movie_title  duration  color  title_year  country  \
# language
# Aboriginal         2            2         2      1           2        2
# Arabic             1            1         1      1           1        1
# Aramaic            1            1         1      1           1        1
# Bosnian            1            1         1      1           1        1
# Cantonese          7            7         7      2           6        1
# Czech              1            1         1      1           1        1
# Danish             3            3         3      1           3        1
# Dari               2            2         2      1           2        2
# Dutch              3            3         3      1           3        1
# English         3628         3528       145      2          72       34
# Filipino           1            1         1      1           1        1
# French            33           33        25      2          16        3
# ...

# %%
imdb.groupby('country')['net_USD'].sum().sort_values()
# Out:
# country
# South Korea      -16497512446
# Japan             -6370750425
# Hungary           -2496624809
# France            -1248596195
# China              -940252093
# Thailand           -896538009
# Spain              -873791257
# India              -698767449
# Germany            -499118576
# Hong Kong          -183809122
# Czech Republic     -142565684
# Denmark            -112533778
# Italy              -102726799
# New Line            -83287549
# Norway              -64695451
# Ireland             -30802607
# Russia              -29742221
# Aruba               -24923864
# Netherlands         -23845335
# Georgia             -19982851
# Taiwan              -14386444
# Greece              -14292206
# Chile               -13811358
# Belgium             -13642958
# Iran                 -4992326
# Brazil               -4637130
# Iceland              -3780041
# Finland              -3238291
# West Germany         -2566866
# Poland               -1421092
# ...

# %%
imdb.groupby('title_year')['budget_USD'].mean()
# Out:
# title_year
# 1927    6.000000e+06
# 1929    3.790000e+05
# 1933    4.390000e+05
# 1935    6.090000e+05
# 1936    1.500000e+06
# 1937    2.000000e+06
# 1939    3.388500e+06
# 1940    2.600000e+06
# 1946    5.050000e+06
# 1947    2.300000e+06
# 1948    3.700000e+06
# 1950    3.768785e+06
# 1952    4.000000e+06
# 1953    5.000000e+06
# 1954    1.455000e+06
# 1957    3.000000e+06
# 1959    2.883848e+06
# 1960    8.069470e+05
# 1961    6.000000e+06
# 1962    8.050000e+06
# 1963    1.655750e+07
# 1964    4.486667e+06
# 1965    1.040000e+07
# 1967    9.500000e+06
# 1968    1.100000e+07
# 1969    4.866667e+06
# 1970    1.287500e+07
# 1971    5.566667e+06
# 1972    3.005000e+06
# 1973    4.355400e+06
#             ...
# 1987    1.393966e+07
# 1988    5.147931e+07
# 1989    1.889562e+07
# 1990    3.256389e+07
# 1991    2.599910e+07
# 1992    2.598203e+07
# 1993    2.147907e+07
# 1994    2.940635e+07
# 1995    3.324886e+07
# 1996    3.272521e+07
# 1997    6.145917e+07
# 1998    4.091203e+07
# ...

# %%
imdb.groupby('movie_title')['net_USD'].sum().sort_values()
# Out:
# movie_title
# The Host                                         -12226681589
# Lady Vengeance                                    -4199788333
# Fateless                                          -2499804112
# Princess Mononoke                                 -2397701809
# Steamboy                                          -2127109510
# Akira                                             -1099560838
# Godzilla 2000                                      -989962610
# Tango                                              -698312689
# Kabhi Alvida Naa Kehna                             -696724557
# Red Cliff                                          -553005191
# The Legend of Suriyothai                           -399545745
# The Messenger: The Story of Joan of Arc            -375868702
# Pan                                                -345105546
# Ong-bak 2                                          -299897945
# John Carter                                        -190641321
# ...
