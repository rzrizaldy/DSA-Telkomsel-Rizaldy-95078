# %% [markdown]
# # Homework Intro to Python
# <br> **Name: Rizaldy Al Kautsar**
# <br> *NIK: 95078*
# <br> Dataset: [Google Play Store Dataset](https://www.kaggle.com/lava18/google-play-store-apps#googleplaystore.csv)

# %% [markdown]
# ***

# %% [markdown]
# # Data and Library Load

# %%
import pandas as pd
import numpy as np

# %%
gplay = pd.read_csv("googleplaystore.csv")
gplay.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
#column&row
print("column:",len(gplay.columns))
print("row:",len(gplay))
# Out:
# column: 13
# row: 10841

# %% [markdown]
# ## Data Cleansing

# %%
gplay.columns = gplay.columns.str.replace(' ', '_')

# %%
gplay.Size=gplay.Size.str.replace('k','e+3')
gplay.Size=gplay.Size.str.replace('M','e+6')
gplay.Size.head()
gplay.Size=gplay.Size.replace('Varies with device',np.nan)
gplay.Size=gplay.Size.replace('1,000+',1000)
gplay.Size=pd.to_numeric(gplay.Size)

# %%
gplay.Installs=gplay.Installs.apply(lambda x: x.strip('+'))
gplay.Installs=gplay.Installs.apply(lambda x: x.replace(',',''))
gplay.Installs=gplay.Installs.replace('Free',np.nan)
gplay.Installs.value_counts()
gplay.Installs=pd.to_numeric(gplay.Installs)

# %%
gplay[~gplay.Reviews.str.isnumeric()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size  Installs Type     Price Content_Rating             Genres  \
# 10472  1000.0       NaN    0  Everyone            NaN  February 11, 2018
#
#       Last_Updated Current_Ver Android_Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
gplay=gplay.drop(gplay.index[10472])

# %%
gplay.Reviews=gplay.Reviews.replace(gplay.Reviews[~gplay.Reviews.str.isnumeric()],np.nan)

# %%
gplay.Price=gplay.Price.apply(lambda x: x.strip('$'))

# %%
sep = ';'
rest = gplay.Genres.apply(lambda x: x.split(sep)[0])
gplay['Pri_Genres']=rest
gplay.Pri_Genres.head()
# Out:
# 0    Art & Design
# 1    Art & Design
# 2    Art & Design
# 3    Art & Design
# 4    Art & Design
# Name: Pri_Genres, dtype: object

# %%
rest = gplay.Genres.apply(lambda x: x.split(sep)[-1])
rest.unique()
gplay['Sec_Genres']=rest
gplay.Sec_Genres.head()
# Out:
# 0    Art & Design
# 1    Pretend Play
# 2    Art & Design
# 3    Art & Design
# 4      Creativity
# Name: Sec_Genres, dtype: object

# %%
twowaytable = pd.crosstab(index=gplay["Pri_Genres"],columns=gplay["Sec_Genres"])
twowaytable.head()
# Out:
# Sec_Genres       Action  Action & Adventure  Adventure  Arcade  Art & Design  \
# Pri_Genres
# Action              365                  17          0       0             0
# Adventure             0                  13         75       0             0
# Arcade                0                  16          0     220             0
# Art & Design          0                   2          0       0            58
# Auto & Vehicles       0                   0          0       0             0
#
# Sec_Genres       Auto & Vehicles  Beauty  Board  Books & Reference  \
# Pri_Genres
# Action                         0       0      0                  0
# Adventure                      0       0      0                  0
# Arcade                         0       0      0                  0
# Art & Design                   0       0      0                  0
# Auto & Vehicles               85       0      0                  0
#
# ...

# %%
gplay.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews        Size    Installs  Type Price Content_Rating  \
# 0     159  19000000.0     10000.0  Free     0       Everyone
# 1     967  14000000.0    500000.0  Free     0       Everyone
# 2   87510   8700000.0   5000000.0  Free     0       Everyone
# 3  215644  25000000.0  50000000.0  Free     0           Teen
# 4     967   2800000.0    100000.0  Free     0       Everyone
#
#                       Genres      Last_Updated         Current_Ver  \
# ...

# %% [markdown]
# ## Exercise

# %%
gplay.Category.nunique()
# Out:
# 33

# %%
gplay.Genres.nunique()
# Out:
# 119

# %%
gplay.Pri_Genres.nunique()
# Out:
# 48

# %%
gplay_cleaned=gplay.drop_duplicates(subset='App', inplace=True)

# %%
gplay['Installs'] = gplay['Installs'].apply(lambda x: x.replace('+', '') if '+' in str(x) else x)

# %%
gplay.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size    Installs  Type Price Content Rating  \
# 0     159   19M      10,000  Free     0       Everyone
# 1     967   14M     500,000  Free     0       Everyone
# 2   87510  8.7M   5,000,000  Free     0       Everyone
# 3  215644   25M  50,000,000  Free     0           Teen
# 4     967  2.8M     100,000  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
gplay['Installs'] = gplay['Installs'].apply(lambda x: x.replace(',', '') if ',' in str(x) else x)

# %%
gplay.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size  Installs  Type Price Content Rating  \
# 0     159   19M     10000  Free     0       Everyone
# 1     967   14M    500000  Free     0       Everyone
# 2   87510  8.7M   5000000  Free     0       Everyone
# 3  215644   25M  50000000  Free     0           Teen
# 4     967  2.8M    100000  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
gplay.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
g = gplay.groupby('Installs')

# %%
g.head()
# Out:
#                                                      App         Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook   ART_AND_DESIGN
# 1                                    Coloring book moana   ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...   ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint   ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book   ART_AND_DESIGN
# 5                             Paper flowers instructions   ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor   ART_AND_DESIGN
# 7                                       Infinite Painter   ART_AND_DESIGN
# 8                                   Garden Coloring Book   ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun   ART_AND_DESIGN
# 10                               Text on Photo - Fonteee   ART_AND_DESIGN
# 11               Name Art Photo Editor - Focus n Filters   ART_AND_DESIGN
# ...

# %%
gplay_selected = gplay[gplay.App.isin(['Subway Surfers','FIFA Soccer','Flipboard: News For Our Time','Pinterest','Dropbox','DU Battery Saver - Battery Charger & Battery Life','WhatsApp Messenger','File Commander - File Manager/Explorer'])]

# %%
gplay_selected[['App','Category']]
# Out:
#                                                      App            Category
# 336                                   WhatsApp Messenger       COMMUNICATION
# 1654                                      Subway Surfers                GAME
# 2552                                           Pinterest              SOCIAL
# 3473                                             Dropbox        PRODUCTIVITY
# 3755                        Flipboard: News For Our Time  NEWS_AND_MAGAZINES
# 8445                                         FIFA Soccer              SPORTS
# 8896   DU Battery Saver - Battery Charger & Battery Life               TOOLS
# 10253             File Commander - File Manager/Explorer            BUSINESS

# %%
gplay_1billion=gplay[gplay.Installs>=1000000000]

# %%
gplay_1billion[['App']]
# Out:
#                                            App
# 152                          Google Play Books
# 335   Messenger – Text and Video Chat for Free
# 336                         WhatsApp Messenger
# 338               Google Chrome: Fast & Secure
# 340                                      Gmail
# 341                                   Hangouts
# 381                         WhatsApp Messenger
# 382   Messenger – Text and Video Chat for Free
# 386                                   Hangouts
# 391              Skype - free IM & video calls
# 411               Google Chrome: Fast & Secure
# 451                                      Gmail
# 464                                   Hangouts
# 468              Skype - free IM & video calls
# 865                          Google Play Games
# 1654                            Subway Surfers
# 1700                            Subway Surfers
# 1750                            Subway Surfers
# 1872                            Subway Surfers
# ...

# %%
gplay[gplay.Category=='COMMUNICATION'][['App','Reviews']].sort_values(['Reviews'], ascending=False)
# Out:
#                                                      App     Reviews
# 381                                   WhatsApp Messenger  69119316.0
# 336                                   WhatsApp Messenger  69119316.0
# 3904                                  WhatsApp Messenger  69109672.0
# 382             Messenger – Text and Video Chat for Free  56646578.0
# 335             Messenger – Text and Video Chat for Free  56642847.0
# 4104            Messenger – Text and Video Chat for Free  56642847.0
# 420          UC Browser - Fast Download Private & Secure  17714850.0
# 378          UC Browser - Fast Download Private & Secure  17712922.0
# 3971         UC Browser - Fast Download Private & Secure  17712922.0
# 6449                         BBM - Free Calls & Messages  12843436.0
# 406                          BBM - Free Calls & Messages  12842860.0
# 4676                                     Viber Messenger  11335481.0
# 467                                      Viber Messenger  11335255.0
# ...

# %%
gplay[gplay.Category=='GAME'][['App','Rating','Installs']].sort_values(['Installs','Rating'], ascending=False)
# Out:
#                                                      App  Rating      Installs
# 1654                                      Subway Surfers     4.5  1.000000e+09
# 1700                                      Subway Surfers     4.5  1.000000e+09
# 1750                                      Subway Surfers     4.5  1.000000e+09
# 1872                                      Subway Surfers     4.5  1.000000e+09
# 1917                                      Subway Surfers     4.5  1.000000e+09
# 3896                                      Subway Surfers     4.5  1.000000e+09
# 1722                                      My Talking Tom     4.5  5.000000e+08
# 1908                                      My Talking Tom     4.5  5.000000e+08
# 1655                                    Candy Crush Saga     4.4  5.000000e+08
# 1705                                    Candy Crush Saga     4.4  5.000000e+08
# 1751                                    Candy Crush Saga     4.4  5.000000e+08
# ...
